# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# The main goal of this notebook is to determine the migration rates into and out of the state of West Virginia. A method for cleaning the data so that it can be used in general is the first step, then creating relevant visuals, and finally comparing the visuals from year to year. All data is obtained from the [US Census Bureau](https://www.census.gov/data/tables/time-series/demo/geographic-mobility/state-to-state-migration.html). I'll start with the year 2010 & on.

# %%
pwd
# Out:
# 'C:\\Users\\Mark\\Documents\\Data\\Migration\\WV'

# %%
data_dct={}
for i in range(9):
    data_dct[i]=pd.read_excel(r'State_to_State_Migrations_Table_201'+str(i)+'.xls')

# %% [markdown]
# Let's get some info about what this spreadsheet looks like.

# %%
data_dct[0].head(25)
# Out:
#    Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 45 through 47.  \
# 0     Table 1.  State-to-State Migration Flows*: 2010
# 1   Dataset: 2010 American Community Survey 1-Year...
# 2                Universe: Population 1 year and over
# 3                                                 NaN
# 4                             Current residence in --
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                      United States1
# 9                                                 NaN
# 10                                            Alabama
# 11                                             Alaska
# 12                                            Arizona
# 13                                           Arkansas
# 14                                         California
# ...

# %%
data_dct[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Columns: 130 entries, Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 45 through 47. to Unnamed: 129
# dtypes: object(130)
# memory usage: 85.4+ KB

# %% [markdown]
# This is an absolute nightmare. I'll do my best to make it pretty.

# %%
data_dct[0]=data_dct[0].drop([0,1,2,3,79,80,81,82,83]).reset_index().drop(['index'], axis=1)
data_dct[0].head()
# Out:
#   Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 45 through 47.  \
# 0                            Current residence in --
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                     United States1
#
#                    Unnamed: 1 Unnamed: 2             Unnamed: 3 Unnamed: 4  \
# 0  Population 1 year and over        NaN  Same house 1 year ago        NaN
# 1                         NaN        NaN                    NaN        NaN
# 2                    Estimate        MOE               Estimate        MOE
# 3                         NaN        NaN                    NaN        NaN
# 4                   305628607      29823              258552348     236128
#
#                            Unnamed: 5 Unnamed: 6  \
# 0  Same state of residence 1 year ago        NaN
# ...

# %%
data_dct[0].columns = data_dct[0].iloc[0]
data_dct[0] = data_dct[0][1:]
data_dct[0].head()
# Out:
# 0 Current residence in -- Population 1 year and over    NaN  \
# 1                     NaN                        NaN    NaN
# 2                     NaN                   Estimate    MOE
# 3                     NaN                        NaN    NaN
# 4          United States1                  305628607  29823
# 5                     NaN                        NaN    NaN
#
# 0 Same house 1 year ago     NaN Same state of residence 1 year ago     NaN  \
# 1                   NaN     NaN                                NaN     NaN
# 2              Estimate     MOE                           Estimate     MOE
# 3                   NaN     NaN                                NaN     NaN
# 4             258552348  236128                           38582885  213239
# 5                   NaN     NaN                                NaN     NaN
#
# 0 Different state of residence 1 year ago    NaN       NaN  ...   NaN  \
# 1                                   Total    NaN   Alabama  ...   NaN
# ...

# %%
data_dct[0].dropna(subset=[str(data_dct[0].columns[0])]).reset_index().drop(['index'], axis=1)
# Out:
# 0                             Current residence in --  \
# 0                                      United States1
# 1                                             Alabama
# 2                                              Alaska
# 3                                             Arizona
# 4                                            Arkansas
# 5                                          California
# 6                                            Colorado
# 7                                         Connecticut
# 8                                            Delaware
# 9                               District of Columbia
# 10                                            Florida
# 11                                            Georgia
# 12                                             Hawaii
# 13                                              Idaho
# 14                                           Illinois
# 15                                            Indiana
# ...
